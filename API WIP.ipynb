# %%
#Import necessary packages
import json
import config
import sys
import pandas as pd

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Define function to retrieve API keys from a Json file
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
#Retrieve personal keys for Spotify API 
keys = get_keys("/Users/adinasteinman/.secret/spotify_api.json")
client_id = keys['client_id']
client_secret = keys['client_secret']

# %%
#Access the Spotipy wrapper with client id and client secret credentials 
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
# playlist_id = 'spotify:user:spotifycharts:playlist:37i9dQZEVXbJiZcmkrIHGU'
# results = sp.playlist(playlist_id)
# print(json.dumps(results, indent=4))

# %% [markdown]
# Before we extract our dataset, we will investigate ways to search for artists, songs, albums, etc. through the Spotify API.

# %%
#Use the sp.search method to look up songs by the Artist "The Weeknd"
search_str = 'The Weeknd'
result = sp.search(search_str)
print(result)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=The+Weeknd&type=track&offset=0&limit=10', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}, 'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ', 'id': '1Xyo4u8uXC1ZmMpatF05PJ', 'name': 'The Weeknd', 'type': 'artist', 'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KR', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'}, 'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj', 'id': '4yP0hdKOZPNshxUOjY0cZj', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36', 'width': 64}], 'name': 'After Hours', 'release_date': '2020-03-20', 'release_date_precision': 'day', 'total_tracks': 14, 'type': 'album', 'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}, 'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ', 'id': '1Xyo4u8uXC1ZmMpatF05PJ', 'name': 'The Weeknd', 'type': 'artist', 'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KR', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 200040, 'explicit': False, 'external_ids': {'isrc': 'USUG11904206'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b'}, 'href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b', 'id': '0VjIjW4GlUZAMYd2vXMi3b', 'is_local': False, 'name': 'Blinding Lights', 'popularity': 95, 'preview_url': None, 'track_number': 9, 'type': 'track', 'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}, 'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ', 'id': '1Xyo4u8uXC1ZmMpatF05PJ', 'name': 'The Weeknd', 'type': 'artist', 'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KR', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/a ...

# %%
#Create a query that looks at top tracks from 2020 
track_results = sp.search(q='year:2020', type='track', limit=50)
track_results

# %%
# artist_name = []
# track_name = []
# popularity = []
# track_id = []
# for i in range(0,10000):
#     track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
# #     for i, t in enumerate(track_results['tracks']['items']):
# #         artist_name.append(t['artists'][0]['name'])
# #         track_name.append(t['name'])
# #         track_id.append(t['id'])
# #         popularity.append(t['popularity'])

# %%
# import pandas as pd
# track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
# print(track_dataframe.shape)
# track_dataframe.head()

# %% [markdown]
# Look at all the possible genres in the Spotify database

# %%
#Use the recommendation_genres_seeds method to extract genres 
genres = sp.recommendation_genre_seeds()

# %%
#Print the list of genres 
genres['genres']
# Out:
# ['acoustic',
#  'afrobeat',
#  'alt-rock',
#  'alternative',
#  'ambient',
#  'anime',
#  'black-metal',
#  'bluegrass',
#  'blues',
#  'bossanova',
#  'brazil',
#  'breakbeat',
#  'british',
#  'cantopop',
#  'chicago-house',
#  'children',
#  'chill',
#  'classical',
#  'club',
#  'comedy',
#  'country',
#  'dance',
#  'dancehall',
#  'death-metal',
#  'deep-house',
#  'detroit-techno',
#  'disco',
#  'disney',
#  'drum-and-bass',
#  'dub',
#  'dubstep',
#  'edm',
#  'electro',
#  'electronic',
#  'emo',
#  'folk',
#  'forro',
#  'french',
#  'funk',
#  'garage',
#  'german',
#  'gospel',
#  'goth',
#  'grindcore',
#  'groove',
#  'grunge',
#  'guitar',
#  'happy',
#  'hard-rock',
#  'hardcore',
#  'hardstyle',
#  'heavy-metal',
#  'hip-hop',
#  'holidays',
#  'honky-tonk',
#  'house',
#  'idm',
#  'indian',
#  'indie',
#  'indie-pop',
#  'industrial',
#  'iranian',
#  'j-dance',
#  'j-idol',
#  'j-pop',
#  'j-rock',
#  'jazz',
#  'k-pop',
#  'kids',
#  'latin',
#  'latino',
#  'malay',
#  'mandopop',
#  'metal',
#  'metal-misc',
#  'metalcore',
#  'minimal-techno',
#  'movies',
#  'mpb',
#  'new-age',
#  'new-release',
#  'opera',
#  'pagode',
#  'party',
#  'philippines-opm',
#  'piano',
#  'pop',
#  'pop-film',
#  'post-dubstep',
#  'power-pop',
#  'progressive-house',
#  'psych-rock',
#  'punk',
#  'punk-rock',
#  'r-n-b',
#  'rainy-day',
#  'reggae',
#  'reggaeton',
#  'road-trip',
#  'rock',
#  'rock-n-roll',
#  'rockabilly',
#  'romance',
#  'sad',
#  'salsa',
#  'samba',
#  'sertanejo',
#  'show-tunes',
#  'singer-songwriter',
#  'ska',
#  'sleep',
#  'songwriter',
#  'soul',
#  'soundtracks',
#  'spanish',
#  'study',
#  'summer',
#  'swedish',
#  'synth-pop',
#  'tango',
#  'techno',
#  'trance',
#  'trip-hop',
#  'turkish',
#  'work-out',
#  'world-music']

# %%
#Extract specific information from the "acoustic" genre: find the name of the third song
acoustics = sp.search(q='genre: acoustic', limit=5, type='track')['tracks']['items']
acoustics[3]['name']
# Out:
# 'Come On Get Higher'

# %%
#Creative a variable called 'hugeplaylist' that extracts information from a specific playlist using its playlist id  
hugeplaylist = sp.user_playlist_tracks(playlist_id="54nv8jbrm4JoHEZ49Qvjgl", offset=100)["items"]

# %% [markdown]
# #Other

# %%
hugeplaylist[0]['track']['name']
# Out:
# 'Turning Tables'

# %%
hugeplaylist[0]['track']['album']['release_date']
# Out:
# '2011-01-19'

# %%
def analyze_playlist(creator, playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist","album","track_name",  "track_id","danceability","energy","key","loudness","mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
    
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Create empty dict
        playlist_features = {}
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["release_date"] = track["track"]["album"]["release_date"]
        playlist_features["track_id"] = track["track"]["id"]
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
playlist_creator = "spotify"
playlist_id = "54nv8jbrm4JoHEZ49Qvjgl"

# %%
analyze_playlist(playlist_creator, playlist_id)
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                                 album         artist  \
# 0   Katy Perry - Teenage Dream: The Complete Confe...     Katy Perry
# 1                                   Dreaming Out Loud    OneRepublic
# 2                                       Back To Black  Amy Winehouse
# 3                                          The Script     The Script
# 4                                                  21          Adele
# ..                                                ...            ...
# 95                                                X&Y       Coldplay
# 96                                  Come Away With Me    Norah Jones
# 97                               Eye To The Telescope    KT Tunstall
# 98                                                  4        Beyoncé
# 99                       Good Girl Gone Bad: Reloaded        Rihanna
#
#     danceability duration_ms  energy instrumentalness key  liveness  loudness  \
# 0          0.638      227880   0.826                0   8    0.0803    -4.968
# 1          0.397      266227   0.817         8.16e-06   2    0.3160    -5.495
# 2          0.384      221200   0.527                0  11    0.1560    -5.294
# 3          0.609      241467   0.629                0  10    0.0978    -5.024
# 4          0.729      228293   0.756                0   8    0.0527    -5.119
# ..           ...         ...     ...              ...  ..       ...       ...
# 95         0.514      287907   0.898           0.0345  11    0.0746    -6.765
# 96         0.732      186147   0.198          1.1e-05   5    0.0659   -11.775
# 97         0.748      172373   0.786                0   4    0.3400    -7.788
# 98         0.665      212147   0.787                0   5    0.2190    -5.730
# 99         0.835      267080   0.669         6.92e-05   6    0.0535    -5.582
#
#    mode release_date  speechiness    tempo time_signature  \
# 0     1   2012-03-12       0.0479  124.072              4
# 1     1   2007-01-01       0.0420  158.004              4
# 2     0   2006-01-01       0.0269  100.730              3
# 3     1   2008-09-08       0.0264   99.955              4
# 4     1   2011-01-19       0.0294  104.945              4
# ..  ...          ...          ...      ...            ...
# 95    0   2005-06-07       0.0577  123.067              4
# 96    1   2002-02-26       0.0280   88.174              4
# 97    0   2005-01-01       0.0641  104.833              4
# 98    1   2011-06-24       0.1510  167.349              4
# 99    0   2008-06-02       0.0643  122.668              4
#
#                   track_id                       track_name  valence
# 0   4lCv7b86sLynZbXhfScfm2                         Firework    0.649
# 1   1Jx69b09LKTuBQxkEiFfVX                       All We Are    0.416
# 2   4u83mwF5tUuWlXS86UOXdu                    Wake Up Alone    0.222
# 3   4Musyaro0NM5Awx8b5c627       The Man Who Can't Be Moved    0.325
# 4   1CkvWZme3pRgbzaxZnTl5X              Rolling in the Deep    0.522
# ..                     ...                              ...      ...
# 95  7clUVcSOtkNWa58Gw5RfD4                   Speed of Sound    0.353
# 96  6ybViy2qrO9sIi41EgRJgx                   Don't Know Why    0.618
# 97  0qAMjeQFyd1qD0LDiV8gWp  Black Horse And The Cherry Tree    0.917
# 98  3axkNosdVQLZiq1HakuGhc                        Countdown    0.699
# 99  6tXjP6xgPJ7Xr1igrO6bOE             Don't Stop The Music    0.542
#
# [100 rows x 17 columns]

# %%
# In [14]:
# # Pull the data of all 10,000 rows of data across all 500 pages. Append this to a lit called "finallist" which will contain the data of movies, sorted by the most popular first.

# finallist=[]
# n=0
# while n<500:
#     n+=1
#     url='http://api.themoviedb.org/3/discover/movie?&sort_by=popularity.desc&offset=20&page={}&api_key='.format(n)
#     req=requests.get(url+api_key).json()
#     results=req['results']
#     finallist.extend(results)
#     time.sleep(2)

# %%
def df_playlist(playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist","album","track_name", "release_date", "track_id"]
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    playlist_features = {}
    counter=0
    for track in playlist_id:
        if track["track"]!=None:
            counter+=1
            playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
            playlist_features["album"] = track["track"]["album"]["name"]
            playlist_features["track_name"] = track["track"]["name"]
            playlist_features["release_date"] = track["track"]["album"]["release_date"]
            playlist_features["track_id"] = track["track"]["id"]
        
            track_df = pd.DataFrame(playlist_features, index = [0])
            playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
            
    return playlist_df

# %%
df_playlist(playlist).to_csv('data')

# %%
df_playlist(playlist)
# Out:
#              artist                                         album  \
# 0  Phillip Phillips  The World From The Side Of The Moon (Deluxe)
#
#          track_name release_date                track_id
# 0  Gone, Gone, Gone   2013-01-01  5L79aNYCTKiZq7vaOElXYj

# %%
p1 = sp.user_playlist_tracks(playlist_id="54nv8jbrm4JoHEZ49Qvjgl")
p1
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/54nv8jbrm4JoHEZ49Qvjgl/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5BvgP623rtvlc0HDcpzquz'},
#      'href': 'https://api.spotify.com/v1/albums/5BvgP623rtvlc0HDcpzquz',
#      'id': '5BvgP623rtvlc0HDcpzquz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273937af329667311f4b2831616',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02937af329667311f4b2831616',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851937af329667311f4b2831616',
#        'width': 64}],
#      'name': 'Katy Perry - Teenage Dream: The Complete Confection',
#      'release_date': '2012-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:5BvgP623rtvlc0HDcpzquz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 227880,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA21001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4lCv7b86sLynZbXhfScfm2'},
#     'href': 'https://api.spotify.com/v1/tracks/4lCv7b86sLynZbXhfScfm2',
#     'id': '4lCv7b86sLynZbXhfScfm2',
#     'is_local': False,
#     'name': 'Firework',
#     'popularity': 72,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4lCv7b86sLynZbXhfScfm2'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#        'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#        'id': '5Pwc4xIPtQLFEnJriah9YJ',
#        'name': 'OneRepublic',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KSpGeDoNjqCKg6HL8LAyI'},
#      'href': 'https://api.spotify.com/v1/albums/2KSpGeDoNjqCKg6HL8LAyI',
#      'id': '2KSpGeDoNjqCKg6HL8LAyI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334ef81d1ff3b4682a4e97f70',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234ef81d1ff3b4682a4e97f70',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134ef81d1ff3b4682a4e97f70',
#        'width': 64}],
#      'name': 'Dreaming Out Loud',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2KSpGeDoNjqCKg6HL8LAyI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#       'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#       'id': '5Pwc4xIPtQLFEnJriah9YJ',
#       'name': 'OneRepublic',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 266226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70758797'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Jx69b09LKTuBQxkEiFfVX'},
#     'href': 'https://api.spotify.com/v1/tracks/1Jx69b09LKTuBQxkEiFfVX',
#     'id': '1Jx69b09LKTuBQxkEiFfVX',
#     'is_local': False,
#     'name': 'All We Are',
#     'popularity': 39,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1Jx69b09LKTuBQxkEiFfVX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#        'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#        'id': '6Q192DXotxtaysaqNPy5yR',
#        'name': 'Amy Winehouse',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6GJCGWfI95aeRsdtVB52vc'},
#      'href': 'https://api.spotify.com/v1/albums/6GJCGWfI95aeRsdtVB52vc',
#      'id': '6GJCGWfI95aeRsdtVB52vc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734b6583b0a1505e40779faec6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024b6583b0a1505e40779faec6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514b6583b0a1505e40779faec6',
#        'width': 64}],
#      'name': 'Back To Black',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6GJCGWfI95aeRsdtVB52vc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#       'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#       'id': '6Q192DXotxtaysaqNPy5yR',
#       'name': 'Amy Winehouse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 221200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM70603491'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4u83mwF5tUuWlXS86UOXdu'},
#     'href': 'https://api.spotify.com/v1/tracks/4u83mwF5tUuWlXS86UOXdu',
#     'id': '4u83mwF5tUuWlXS86UOXdu',
#     'is_local': False,
#     'name': 'Wake Up Alone',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4u83mwF5tUuWlXS86UOXdu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#        'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#        'id': '3AQRLZ9PuTAozP28Skbq8V',
#        'name': 'The Script',
#        'type': 'artist',
#        'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/51Hn2Wiq1jmUfI0BLaUhuF'},
#      'href': 'https://api.spotify.com/v1/albums/51Hn2Wiq1jmUfI0BLaUhuF',
#      'id': '51Hn2Wiq1jmUfI0BLaUhuF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b526ba531c80ed208cd428ed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b526ba531c80ed208cd428ed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b526ba531c80ed208cd428ed',
#        'width': 64}],
#      'name': 'The Script',
#      'release_date': '2008-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:51Hn2Wiq1jmUfI0BLaUhuF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#       'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#       'id': '3AQRLZ9PuTAozP28Skbq8V',
#       'name': 'The Script',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 241466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL0800144'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Musyaro0NM5Awx8b5c627'},
#     'href': 'https://api.spotify.com/v1/tracks/4Musyaro0NM5Awx8b5c627',
#     'id': '4Musyaro0NM5Awx8b5c627',
#     'is_local': False,
#     'name': "The Man Who Can't Be Moved",
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/baf6f571aafccb8d577e6ab77c8ff5b01e50d30f?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4Musyaro0NM5Awx8b5c627'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#        'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#        'id': '4dpARuHxo51G3z768sgnrY',
#        'name': 'Adele',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1azUkThwd2HfUDdeNeT147'},
#      'href': 'https://api.spotify.com/v1/albums/1azUkThwd2HfUDdeNeT147',
#      'id': '1azUkThwd2HfUDdeNeT147',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d4056466fc11f6408be2566',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d4056466fc11f6408be2566',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d4056466fc11f6408be2566',
#        'width': 64}],
#      'name': '21',
#      'release_date': '2011-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1azUkThwd2HfUDdeNeT147'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 228293,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS1000335'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1CkvWZme3pRgbzaxZnTl5X'},
#     'href': 'https://api.spotify.com/v1/tracks/1CkvWZme3pRgbzaxZnTl5X',
#     'id': '1CkvWZme3pRgbzaxZnTl5X',
#     'is_local': False,
#     'name': 'Rolling in the Deep',
#     'popularity': 58,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1CkvWZme3pRgbzaxZnTl5X'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TN',
#       'TR',
#       'UA',
#       'UY',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6J84szYCnMfzEcvIcfWMFL'},
#      'href': 'https://api.spotify.com/v1/albums/6J84szYCnMfzEcvIcfWMFL',
#      'id': '6J84szYCnMfzEcvIcfWMFL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273caaa456c44f69f10c8b2aa53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02caaa456c44f69f10c8b2aa53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851caaa456c44f69f10c8b2aa53',
#        'width': 64}],
#      'name': 'Doo-Wops & Hooligans',
#      'release_date': '2010-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6J84szYCnMfzEcvIcfWMFL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TN',
#      'TR',
#      'UA',
#      'UY',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 223253,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21001883'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4lLtanYk6tkMvooU0tWzG8'},
#     'href': 'https://api.spotify.com/v1/tracks/4lLtanYk6tkMvooU0tWzG8',
#     'id': '4lLtanYk6tkMvooU0tWzG8',
#     'is_local': False,
#     'name': 'Grenade',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d6fc23418ef4a090922decfe6a47c7bc87c1d762?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4lLtanYk6tkMvooU0tWzG8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yHr095BMG5I3IRH4ToE5l'},
#      'href': 'https://api.spotify.com/v1/albums/4yHr095BMG5I3IRH4ToE5l',
#      'id': '4yHr095BMG5I3IRH4ToE5l',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ebb720684d839c8909d1dac3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ebb720684d839c8909d1dac3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ebb720684d839c8909d1dac3',
#        'width': 64}],
#      'name': 'The Fame Monster (Deluxe)',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:4yHr095BMG5I3IRH4ToE5l'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 237213,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70824409'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3OT3Kg4jyVkdZm4Ncz6JgX'},
#     'href': 'https://api.spotify.com/v1/tracks/3OT3Kg4jyVkdZm4Ncz6JgX',
#     'id': '3OT3Kg4jyVkdZm4Ncz6JgX',
#     'is_local': False,
#     'name': 'Poker Face',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:3OT3Kg4jyVkdZm4Ncz6JgX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7H55rcKCfwqkyDFH9wpKM6'},
#        'href': 'https://api.spotify.com/v1/artists/7H55rcKCfwqkyDFH9wpKM6',
#        'id': '7H55rcKCfwqkyDFH9wpKM6',
#        'name': 'Christina Perri',
#        'type': 'artist',
#        'uri': 'spotify:artist:7H55rcKCfwqkyDFH9wpKM6'}],
#      'available_markets': ['AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'KR',
#       'KZ',
#       'LT',
#       'LU',
#       'LV',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3XNK8vPk3O1rjhDZyOMJ6n'},
#      'href': 'https://api.spotify.com/v1/albums/3XNK8vPk3O1rjhDZyOMJ6n',
#      'id': '3XNK8vPk3O1rjhDZyOMJ6n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27326a2f5224465a369f8abbf88',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0226a2f5224465a369f8abbf88',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485126a2f5224465a369f8abbf88',
#        'width': 64}],
#      'name': 'lovestrong.',
#      'release_date': '2011-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3XNK8vPk3O1rjhDZyOMJ6n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7H55rcKCfwqkyDFH9wpKM6'},
#       'href': 'https://api.spotify.com/v1/artists/7H55rcKCfwqkyDFH9wpKM6',
#       'id': '7H55rcKCfwqkyDFH9wpKM6',
#       'name': 'Christina Perri',
#       'type': 'artist',
#       'uri': 'spotify:artist:7H55rcKCfwqkyDFH9wpKM6'}],
#     'available_markets': ['AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'KR',
#      'KZ',
#      'LT',
#      'LU',
#      'LV',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 233480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21100501'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21JTgoZLDB2F4Fx0uRCmTL'},
#     'href': 'https://api.spotify.com/v1/tracks/21JTgoZLDB2F4Fx0uRCmTL',
#     'id': '21JTgoZLDB2F4Fx0uRCmTL',
#     'is_local': False,
#     'name': 'the lonely',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3090bd40ff8c1ff674357fafb45c066339645d11?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:21JTgoZLDB2F4Fx0uRCmTL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#        'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#        'id': '4gzpq5DPGxSnKTe4SA8HAU',
#        'name': 'Coldplay',
#        'type': 'artist',
#        'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#      'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra',
#      'id': '6ZG5lRT77aJ3btmArcykra',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733d92b2ad5af9fbc8637425f0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023d92b2ad5af9fbc8637425f0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513d92b2ad5af9fbc8637425f0',
#        'width': 64}],
#      'name': 'Parachutes',
#      'release_date': '2000-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 266773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE0000267'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg'},
#     'href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg',
#     'id': '3AJwUDP919kvQ9QcozQPxg',
#     'is_local': False,
#     'name': 'Yellow',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/26ad91af2f13c2b7729cbc70856ce43f4c790a7b?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#        'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#        'id': '2Sqr0DXoaYABbjBo9HaMkM',
#        'name': 'Sara Bareilles',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Z9WUERfMjOgQ6ze9TcGbF'},
#      'href': 'https://api.spotify.com/v1/albums/2Z9WUERfMjOgQ6ze9TcGbF',
#      'id': '2Z9WUERfMjOgQ6ze9TcGbF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c3e0a58f3ee28af2922e351',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c3e0a58f3ee28af2922e351',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c3e0a58f3ee28af2922e351',
#        'width': 64}],
#      'name': 'Little Voice',
#      'release_date': '2007-07-03',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2Z9WUERfMjOgQ6ze9TcGbF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#       'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#       'id': '2Sqr0DXoaYABbjBo9HaMkM',
#       'name': 'Sara Bareilles',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 232760,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10700068'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oa14QBfWRDfJy2agySy0L'},
#     'href': 'https://api.spotify.com/v1/tracks/4oa14QBfWRDfJy2agySy0L',
#     'id': '4oa14QBfWRDfJy2agySy0L',
#     'is_local': False,
#     'name': 'Gravity',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b380e59d1b18642085530b4d86f78376358c9892?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:4oa14QBfWRDfJy2agySy0L'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#        'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#        'id': '3BmGtnKgCSGYIUhmivXKWX',
#        'name': 'Kelly Clarkson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0VmE95pr5TSpZWucfyhO5e'},
#      'href': 'https://api.spotify.com/v1/albums/0VmE95pr5TSpZWucfyhO5e',
#      'id': '0VmE95pr5TSpZWucfyhO5e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273af384269742c6b04308c1be8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02af384269742c6b04308c1be8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851af384269742c6b04308c1be8',
#        'width': 64}],
#      'name': 'Stronger (Deluxe Version)',
#      'release_date': '2011-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:0VmE95pr5TSpZWucfyhO5e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#       'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#       'id': '3BmGtnKgCSGYIUhmivXKWX',
#       'name': 'Kelly Clarkson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 232520,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCTA1100219'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7CHIJREUYyM7vndBQE6iMy'},
#     'href': 'https://api.spotify.com/v1/tracks/7CHIJREUYyM7vndBQE6iMy',
#     'id': '7CHIJREUYyM7vndBQE6iMy',
#     'is_local': False,
#     'name': 'Mr. Know It All',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0af54fd78b3b5e2c115b75aa43d0567eefe0a137?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7CHIJREUYyM7vndBQE6iMy'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AsusXITU8P25dlRNhcAbG'},
#        'href': 'https://api.spotify.com/v1/artists/2AsusXITU8P25dlRNhcAbG',
#        'id': '2AsusXITU8P25dlRNhcAbG',
#        'name': 'Gotye',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AsusXITU8P25dlRNhcAbG'}],
#      'available_markets': ['CA', 'CR', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1HjSyGjmLNjRAKgT9t1cna'},
#      'href': 'https://api.spotify.com/v1/albums/1HjSyGjmLNjRAKgT9t1cna',
#      'id': '1HjSyGjmLNjRAKgT9t1cna',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e1d47c00ddecbfb810c807ed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e1d47c00ddecbfb810c807ed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e1d47c00ddecbfb810c807ed',
#        'width': 64}],
#      'name': 'Making Mirrors',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1HjSyGjmLNjRAKgT9t1cna'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AsusXITU8P25dlRNhcAbG'},
#       'href': 'https://api.spotify.com/v1/artists/2AsusXITU8P25dlRNhcAbG',
#       'id': '2AsusXITU8P25dlRNhcAbG',
#       'name': 'Gotye',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AsusXITU8P25dlRNhcAbG'}],
#     'available_markets': ['CA', 'CR', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 279013,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUZS21100044'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6l8AiDMKX10Nu2IZJcPb4i'},
#     'href': 'https://api.spotify.com/v1/tracks/6l8AiDMKX10Nu2IZJcPb4i',
#     'id': '6l8AiDMKX10Nu2IZJcPb4i',
#     'is_local': False,
#     'name': 'In Your Light',
#     'popularity': 29,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6l8AiDMKX10Nu2IZJcPb4i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LpLGlgRS1IKPPwElnpW35'},
#        'href': 'https://api.spotify.com/v1/artists/3LpLGlgRS1IKPPwElnpW35',
#        'id': '3LpLGlgRS1IKPPwElnpW35',
#        'name': 'James Morrison',
#        'type': 'artist',
#        'uri': 'spotify:artist:3LpLGlgRS1IKPPwElnpW35'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0cHXj1g4NdFEQinwxj4soZ'},
#      'href': 'https://api.spotify.com/v1/albums/0cHXj1g4NdFEQinwxj4soZ',
#      'id': '0cHXj1g4NdFEQinwxj4soZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a0f8cd0dcd687ac5ac35a497',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a0f8cd0dcd687ac5ac35a497',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a0f8cd0dcd687ac5ac35a497',
#        'width': 64}],
#      'name': 'Undiscovered (International Version)',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0cHXj1g4NdFEQinwxj4soZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LpLGlgRS1IKPPwElnpW35'},
#       'href': 'https://api.spotify.com/v1/artists/3LpLGlgRS1IKPPwElnpW35',
#       'id': '3LpLGlgRS1IKPPwElnpW35',
#       'name': 'James Morrison',
#       'type': 'artist',
#       'uri': 'spotify:artist:3LpLGlgRS1IKPPwElnpW35'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
# ...
#        'name': 'Norah Jones',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Kx7MNY7cI1ENniW7vT30N'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1JvoMzqg04nC29gam4Qaiq'},
#      'href': 'https://api.spotify.com/v1/albums/1JvoMzqg04nC29gam4Qaiq',
#      'id': '1JvoMzqg04nC29gam4Qaiq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737862811f80ae629373954f0d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027862811f80ae629373954f0d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517862811f80ae629373954f0d',
#        'width': 64}],
#      'name': 'Come Away With Me',
#      'release_date': '2002-02-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1JvoMzqg04nC29gam4Qaiq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Kx7MNY7cI1ENniW7vT30N'},
#       'href': 'https://api.spotify.com/v1/artists/2Kx7MNY7cI1ENniW7vT30N',
#       'id': '2Kx7MNY7cI1ENniW7vT30N',
#       'name': 'Norah Jones',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Kx7MNY7cI1ENniW7vT30N'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 186146,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBN20100529'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ybViy2qrO9sIi41EgRJgx'},
#     'href': 'https://api.spotify.com/v1/tracks/6ybViy2qrO9sIi41EgRJgx',
#     'id': '6ybViy2qrO9sIi41EgRJgx',
#     'is_local': False,
#     'name': "Don't Know Why",
#     'popularity': 72,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6ybViy2qrO9sIi41EgRJgx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zzrJD2jXrE9dZ1AklRFcL'},
#        'href': 'https://api.spotify.com/v1/artists/5zzrJD2jXrE9dZ1AklRFcL',
#        'id': '5zzrJD2jXrE9dZ1AklRFcL',
#        'name': 'KT Tunstall',
#        'type': 'artist',
#        'uri': 'spotify:artist:5zzrJD2jXrE9dZ1AklRFcL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3j70PDKieTWQAwas3bPHRZ'},
#      'href': 'https://api.spotify.com/v1/albums/3j70PDKieTWQAwas3bPHRZ',
#      'id': '3j70PDKieTWQAwas3bPHRZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273183730e8038fa632b2c227da',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02183730e8038fa632b2c227da',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851183730e8038fa632b2c227da',
#        'width': 64}],
#      'name': 'Eye To The Telescope',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3j70PDKieTWQAwas3bPHRZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zzrJD2jXrE9dZ1AklRFcL'},
#       'href': 'https://api.spotify.com/v1/artists/5zzrJD2jXrE9dZ1AklRFcL',
#       'id': '5zzrJD2jXrE9dZ1AklRFcL',
#       'name': 'KT Tunstall',
#       'type': 'artist',
#       'uri': 'spotify:artist:5zzrJD2jXrE9dZ1AklRFcL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBGLM0400102'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0qAMjeQFyd1qD0LDiV8gWp'},
#     'href': 'https://api.spotify.com/v1/tracks/0qAMjeQFyd1qD0LDiV8gWp',
#     'id': '0qAMjeQFyd1qD0LDiV8gWp',
#     'is_local': False,
#     'name': 'Black Horse And The Cherry Tree',
#     'popularity': 59,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0qAMjeQFyd1qD0LDiV8gWp'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1gIC63gC3B7o7FfpPACZQJ'},
#      'href': 'https://api.spotify.com/v1/albums/1gIC63gC3B7o7FfpPACZQJ',
#      'id': '1gIC63gC3B7o7FfpPACZQJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ff5429125128b43572dbdccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ff5429125128b43572dbdccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ff5429125128b43572dbdccd',
#        'width': 64}],
#      'name': '4',
#      'release_date': '2011-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1gIC63gC3B7o7FfpPACZQJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212146,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11102909'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3axkNosdVQLZiq1HakuGhc'},
#     'href': 'https://api.spotify.com/v1/tracks/3axkNosdVQLZiq1HakuGhc',
#     'id': '3axkNosdVQLZiq1HakuGhc',
#     'is_local': False,
#     'name': 'Countdown',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ad046f8b135785f005bf84b63d657299cd6010ee?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3axkNosdVQLZiq1HakuGhc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#        'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#        'id': '5pKCCKE2ajJHZ9KAiaK11H',
#        'name': 'Rihanna',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1G2ZRwcqN6warfakvcPgEs'},
#      'href': 'https://api.spotify.com/v1/albums/1G2ZRwcqN6warfakvcPgEs',
#      'id': '1G2ZRwcqN6warfakvcPgEs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad4ef80be7f5e15d64ac5c25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad4ef80be7f5e15d64ac5c25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad4ef80be7f5e15d64ac5c25',
#        'width': 64}],
#      'name': 'Good Girl Gone Bad: Reloaded',
#      'release_date': '2008-06-02',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1G2ZRwcqN6warfakvcPgEs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 267080,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70734700'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6tXjP6xgPJ7Xr1igrO6bOE'},
#     'href': 'https://api.spotify.com/v1/tracks/6tXjP6xgPJ7Xr1igrO6bOE',
#     'id': '6tXjP6xgPJ7Xr1igrO6bOE',
#     'is_local': False,
#     'name': "Don't Stop The Music",
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6tXjP6xgPJ7Xr1igrO6bOE'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/54nv8jbrm4JoHEZ49Qvjgl/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 9964}

# %%
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/54nv8jbrm4JoHEZ49Qvjgl/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5BvgP623rtvlc0HDcpzquz'},
#      'href': 'https://api.spotify.com/v1/albums/5BvgP623rtvlc0HDcpzquz',
#      'id': '5BvgP623rtvlc0HDcpzquz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273937af329667311f4b2831616',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02937af329667311f4b2831616',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851937af329667311f4b2831616',
#        'width': 64}],
#      'name': 'Katy Perry - Teenage Dream: The Complete Confection',
#      'release_date': '2012-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:5BvgP623rtvlc0HDcpzquz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 227880,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA21001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4lCv7b86sLynZbXhfScfm2'},
#     'href': 'https://api.spotify.com/v1/tracks/4lCv7b86sLynZbXhfScfm2',
#     'id': '4lCv7b86sLynZbXhfScfm2',
#     'is_local': False,
#     'name': 'Firework',
#     'popularity': 72,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4lCv7b86sLynZbXhfScfm2'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#        'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#        'id': '5Pwc4xIPtQLFEnJriah9YJ',
#        'name': 'OneRepublic',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KSpGeDoNjqCKg6HL8LAyI'},
#      'href': 'https://api.spotify.com/v1/albums/2KSpGeDoNjqCKg6HL8LAyI',
#      'id': '2KSpGeDoNjqCKg6HL8LAyI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334ef81d1ff3b4682a4e97f70',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234ef81d1ff3b4682a4e97f70',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134ef81d1ff3b4682a4e97f70',
#        'width': 64}],
#      'name': 'Dreaming Out Loud',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2KSpGeDoNjqCKg6HL8LAyI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#       'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#       'id': '5Pwc4xIPtQLFEnJriah9YJ',
#       'name': 'OneRepublic',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 266226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70758797'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Jx69b09LKTuBQxkEiFfVX'},
#     'href': 'https://api.spotify.com/v1/tracks/1Jx69b09LKTuBQxkEiFfVX',
#     'id': '1Jx69b09LKTuBQxkEiFfVX',
#     'is_local': False,
#     'name': 'All We Are',
#     'popularity': 39,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1Jx69b09LKTuBQxkEiFfVX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#        'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#        'id': '6Q192DXotxtaysaqNPy5yR',
#        'name': 'Amy Winehouse',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6GJCGWfI95aeRsdtVB52vc'},
#      'href': 'https://api.spotify.com/v1/albums/6GJCGWfI95aeRsdtVB52vc',
#      'id': '6GJCGWfI95aeRsdtVB52vc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734b6583b0a1505e40779faec6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024b6583b0a1505e40779faec6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514b6583b0a1505e40779faec6',
#        'width': 64}],
#      'name': 'Back To Black',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6GJCGWfI95aeRsdtVB52vc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#       'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#       'id': '6Q192DXotxtaysaqNPy5yR',
#       'name': 'Amy Winehouse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 221200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM70603491'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4u83mwF5tUuWlXS86UOXdu'},
#     'href': 'https://api.spotify.com/v1/tracks/4u83mwF5tUuWlXS86UOXdu',
#     'id': '4u83mwF5tUuWlXS86UOXdu',
#     'is_local': False,
#     'name': 'Wake Up Alone',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4u83mwF5tUuWlXS86UOXdu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#        'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#        'id': '3AQRLZ9PuTAozP28Skbq8V',
#        'name': 'The Script',
#        'type': 'artist',
#        'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/51Hn2Wiq1jmUfI0BLaUhuF'},
#      'href': 'https://api.spotify.com/v1/albums/51Hn2Wiq1jmUfI0BLaUhuF',
#      'id': '51Hn2Wiq1jmUfI0BLaUhuF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b526ba531c80ed208cd428ed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b526ba531c80ed208cd428ed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b526ba531c80ed208cd428ed',
#        'width': 64}],
#      'name': 'The Script',
#      'release_date': '2008-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:51Hn2Wiq1jmUfI0BLaUhuF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#       'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#       'id': '3AQRLZ9PuTAozP28Skbq8V',
#       'name': 'The Script',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 241466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL0800144'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Musyaro0NM5Awx8b5c627'},
#     'href': 'https://api.spotify.com/v1/tracks/4Musyaro0NM5Awx8b5c627',
#     'id': '4Musyaro0NM5Awx8b5c627',
#     'is_local': False,
#     'name': "The Man Who Can't Be Moved",
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/baf6f571aafccb8d577e6ab77c8ff5b01e50d30f?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4Musyaro0NM5Awx8b5c627'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#        'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#        'id': '4dpARuHxo51G3z768sgnrY',
#        'name': 'Adele',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1azUkThwd2HfUDdeNeT147'},
#      'href': 'https://api.spotify.com/v1/albums/1azUkThwd2HfUDdeNeT147',
#      'id': '1azUkThwd2HfUDdeNeT147',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d4056466fc11f6408be2566',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d4056466fc11f6408be2566',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d4056466fc11f6408be2566',
#        'width': 64}],
#      'name': '21',
#      'release_date': '2011-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1azUkThwd2HfUDdeNeT147'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 228293,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS1000335'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1CkvWZme3pRgbzaxZnTl5X'},
#     'href': 'https://api.spotify.com/v1/tracks/1CkvWZme3pRgbzaxZnTl5X',
#     'id': '1CkvWZme3pRgbzaxZnTl5X',
#     'is_local': False,
#     'name': 'Rolling in the Deep',
#     'popularity': 58,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1CkvWZme3pRgbzaxZnTl5X'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TN',
#       'TR',
#       'UA',
#       'UY',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6J84szYCnMfzEcvIcfWMFL'},
#      'href': 'https://api.spotify.com/v1/albums/6J84szYCnMfzEcvIcfWMFL',
#      'id': '6J84szYCnMfzEcvIcfWMFL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273caaa456c44f69f10c8b2aa53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02caaa456c44f69f10c8b2aa53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851caaa456c44f69f10c8b2aa53',
#        'width': 64}],
#      'name': 'Doo-Wops & Hooligans',
#      'release_date': '2010-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6J84szYCnMfzEcvIcfWMFL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TN',
#      'TR',
#      'UA',
#      'UY',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 223253,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21001883'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4lLtanYk6tkMvooU0tWzG8'},
#     'href': 'https://api.spotify.com/v1/tracks/4lLtanYk6tkMvooU0tWzG8',
#     'id': '4lLtanYk6tkMvooU0tWzG8',
#     'is_local': False,
#     'name': 'Grenade',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d6fc23418ef4a090922decfe6a47c7bc87c1d762?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4lLtanYk6tkMvooU0tWzG8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yHr095BMG5I3IRH4ToE5l'},
#      'href': 'https://api.spotify.com/v1/albums/4yHr095BMG5I3IRH4ToE5l',
#      'id': '4yHr095BMG5I3IRH4ToE5l',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ebb720684d839c8909d1dac3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ebb720684d839c8909d1dac3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ebb720684d839c8909d1dac3',
#        'width': 64}],
#      'name': 'The Fame Monster (Deluxe)',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:4yHr095BMG5I3IRH4ToE5l'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 237213,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70824409'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3OT3Kg4jyVkdZm4Ncz6JgX'},
#     'href': 'https://api.spotify.com/v1/tracks/3OT3Kg4jyVkdZm4Ncz6JgX',
#     'id': '3OT3Kg4jyVkdZm4Ncz6JgX',
#     'is_local': False,
#     'name': 'Poker Face',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:3OT3Kg4jyVkdZm4Ncz6JgX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7H55rcKCfwqkyDFH9wpKM6'},
#        'href': 'https://api.spotify.com/v1/artists/7H55rcKCfwqkyDFH9wpKM6',
#        'id': '7H55rcKCfwqkyDFH9wpKM6',
#        'name': 'Christina Perri',
#        'type': 'artist',
#        'uri': 'spotify:artist:7H55rcKCfwqkyDFH9wpKM6'}],
#      'available_markets': ['AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'KR',
#       'KZ',
#       'LT',
#       'LU',
#       'LV',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3XNK8vPk3O1rjhDZyOMJ6n'},
#      'href': 'https://api.spotify.com/v1/albums/3XNK8vPk3O1rjhDZyOMJ6n',
#      'id': '3XNK8vPk3O1rjhDZyOMJ6n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27326a2f5224465a369f8abbf88',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0226a2f5224465a369f8abbf88',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485126a2f5224465a369f8abbf88',
#        'width': 64}],
#      'name': 'lovestrong.',
#      'release_date': '2011-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3XNK8vPk3O1rjhDZyOMJ6n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7H55rcKCfwqkyDFH9wpKM6'},
#       'href': 'https://api.spotify.com/v1/artists/7H55rcKCfwqkyDFH9wpKM6',
#       'id': '7H55rcKCfwqkyDFH9wpKM6',
#       'name': 'Christina Perri',
#       'type': 'artist',
#       'uri': 'spotify:artist:7H55rcKCfwqkyDFH9wpKM6'}],
#     'available_markets': ['AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'KR',
#      'KZ',
#      'LT',
#      'LU',
#      'LV',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 233480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21100501'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21JTgoZLDB2F4Fx0uRCmTL'},
#     'href': 'https://api.spotify.com/v1/tracks/21JTgoZLDB2F4Fx0uRCmTL',
#     'id': '21JTgoZLDB2F4Fx0uRCmTL',
#     'is_local': False,
#     'name': 'the lonely',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3090bd40ff8c1ff674357fafb45c066339645d11?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:21JTgoZLDB2F4Fx0uRCmTL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#        'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#        'id': '4gzpq5DPGxSnKTe4SA8HAU',
#        'name': 'Coldplay',
#        'type': 'artist',
#        'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#      'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra',
#      'id': '6ZG5lRT77aJ3btmArcykra',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733d92b2ad5af9fbc8637425f0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023d92b2ad5af9fbc8637425f0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513d92b2ad5af9fbc8637425f0',
#        'width': 64}],
#      'name': 'Parachutes',
#      'release_date': '2000-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 266773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE0000267'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg'},
#     'href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg',
#     'id': '3AJwUDP919kvQ9QcozQPxg',
#     'is_local': False,
#     'name': 'Yellow',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/26ad91af2f13c2b7729cbc70856ce43f4c790a7b?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#        'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#        'id': '2Sqr0DXoaYABbjBo9HaMkM',
#        'name': 'Sara Bareilles',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Z9WUERfMjOgQ6ze9TcGbF'},
#      'href': 'https://api.spotify.com/v1/albums/2Z9WUERfMjOgQ6ze9TcGbF',
#      'id': '2Z9WUERfMjOgQ6ze9TcGbF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c3e0a58f3ee28af2922e351',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c3e0a58f3ee28af2922e351',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c3e0a58f3ee28af2922e351',
#        'width': 64}],
#      'name': 'Little Voice',
#      'release_date': '2007-07-03',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2Z9WUERfMjOgQ6ze9TcGbF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#       'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#       'id': '2Sqr0DXoaYABbjBo9HaMkM',
#       'name': 'Sara Bareilles',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 232760,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10700068'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oa14QBfWRDfJy2agySy0L'},
#     'href': 'https://api.spotify.com/v1/tracks/4oa14QBfWRDfJy2agySy0L',
#     'id': '4oa14QBfWRDfJy2agySy0L',
#     'is_local': False,
#     'name': 'Gravity',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b380e59d1b18642085530b4d86f78376358c9892?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:4oa14QBfWRDfJy2agySy0L'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#        'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#        'id': '3BmGtnKgCSGYIUhmivXKWX',
#        'name': 'Kelly Clarkson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0VmE95pr5TSpZWucfyhO5e'},
#      'href': 'https://api.spotify.com/v1/albums/0VmE95pr5TSpZWucfyhO5e',
#      'id': '0VmE95pr5TSpZWucfyhO5e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273af384269742c6b04308c1be8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02af384269742c6b04308c1be8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851af384269742c6b04308c1be8',
#        'width': 64}],
#      'name': 'Stronger (Deluxe Version)',
#      'release_date': '2011-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:0VmE95pr5TSpZWucfyhO5e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#       'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#       'id': '3BmGtnKgCSGYIUhmivXKWX',
#       'name': 'Kelly Clarkson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 232520,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCTA1100219'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7CHIJREUYyM7vndBQE6iMy'},
#     'href': 'https://api.spotify.com/v1/tracks/7CHIJREUYyM7vndBQE6iMy',
#     'id': '7CHIJREUYyM7vndBQE6iMy',
#     'is_local': False,
#     'name': 'Mr. Know It All',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0af54fd78b3b5e2c115b75aa43d0567eefe0a137?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7CHIJREUYyM7vndBQE6iMy'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AsusXITU8P25dlRNhcAbG'},
#        'href': 'https://api.spotify.com/v1/artists/2AsusXITU8P25dlRNhcAbG',
#        'id': '2AsusXITU8P25dlRNhcAbG',
#        'name': 'Gotye',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AsusXITU8P25dlRNhcAbG'}],
#      'available_markets': ['CA', 'CR', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1HjSyGjmLNjRAKgT9t1cna'},
#      'href': 'https://api.spotify.com/v1/albums/1HjSyGjmLNjRAKgT9t1cna',
#      'id': '1HjSyGjmLNjRAKgT9t1cna',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e1d47c00ddecbfb810c807ed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e1d47c00ddecbfb810c807ed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e1d47c00ddecbfb810c807ed',
#        'width': 64}],
#      'name': 'Making Mirrors',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1HjSyGjmLNjRAKgT9t1cna'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AsusXITU8P25dlRNhcAbG'},
#       'href': 'https://api.spotify.com/v1/artists/2AsusXITU8P25dlRNhcAbG',
#       'id': '2AsusXITU8P25dlRNhcAbG',
#       'name': 'Gotye',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AsusXITU8P25dlRNhcAbG'}],
#     'available_markets': ['CA', 'CR', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 279013,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUZS21100044'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6l8AiDMKX10Nu2IZJcPb4i'},
#     'href': 'https://api.spotify.com/v1/tracks/6l8AiDMKX10Nu2IZJcPb4i',
#     'id': '6l8AiDMKX10Nu2IZJcPb4i',
#     'is_local': False,
#     'name': 'In Your Light',
#     'popularity': 29,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6l8AiDMKX10Nu2IZJcPb4i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LpLGlgRS1IKPPwElnpW35'},
#        'href': 'https://api.spotify.com/v1/artists/3LpLGlgRS1IKPPwElnpW35',
#        'id': '3LpLGlgRS1IKPPwElnpW35',
#        'name': 'James Morrison',
#        'type': 'artist',
#        'uri': 'spotify:artist:3LpLGlgRS1IKPPwElnpW35'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0cHXj1g4NdFEQinwxj4soZ'},
#      'href': 'https://api.spotify.com/v1/albums/0cHXj1g4NdFEQinwxj4soZ',
#      'id': '0cHXj1g4NdFEQinwxj4soZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a0f8cd0dcd687ac5ac35a497',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a0f8cd0dcd687ac5ac35a497',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a0f8cd0dcd687ac5ac35a497',
#        'width': 64}],
#      'name': 'Undiscovered (International Version)',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0cHXj1g4NdFEQinwxj4soZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LpLGlgRS1IKPPwElnpW35'},
#       'href': 'https://api.spotify.com/v1/artists/3LpLGlgRS1IKPPwElnpW35',
#       'id': '3LpLGlgRS1IKPPwElnpW35',
#       'name': 'James Morrison',
#       'type': 'artist',
#       'uri': 'spotify:artist:3LpLGlgRS1IKPPwElnpW35'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
# ...
#        'name': 'Norah Jones',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Kx7MNY7cI1ENniW7vT30N'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1JvoMzqg04nC29gam4Qaiq'},
#      'href': 'https://api.spotify.com/v1/albums/1JvoMzqg04nC29gam4Qaiq',
#      'id': '1JvoMzqg04nC29gam4Qaiq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737862811f80ae629373954f0d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027862811f80ae629373954f0d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517862811f80ae629373954f0d',
#        'width': 64}],
#      'name': 'Come Away With Me',
#      'release_date': '2002-02-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1JvoMzqg04nC29gam4Qaiq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Kx7MNY7cI1ENniW7vT30N'},
#       'href': 'https://api.spotify.com/v1/artists/2Kx7MNY7cI1ENniW7vT30N',
#       'id': '2Kx7MNY7cI1ENniW7vT30N',
#       'name': 'Norah Jones',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Kx7MNY7cI1ENniW7vT30N'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 186146,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBN20100529'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ybViy2qrO9sIi41EgRJgx'},
#     'href': 'https://api.spotify.com/v1/tracks/6ybViy2qrO9sIi41EgRJgx',
#     'id': '6ybViy2qrO9sIi41EgRJgx',
#     'is_local': False,
#     'name': "Don't Know Why",
#     'popularity': 72,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6ybViy2qrO9sIi41EgRJgx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zzrJD2jXrE9dZ1AklRFcL'},
#        'href': 'https://api.spotify.com/v1/artists/5zzrJD2jXrE9dZ1AklRFcL',
#        'id': '5zzrJD2jXrE9dZ1AklRFcL',
#        'name': 'KT Tunstall',
#        'type': 'artist',
#        'uri': 'spotify:artist:5zzrJD2jXrE9dZ1AklRFcL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3j70PDKieTWQAwas3bPHRZ'},
#      'href': 'https://api.spotify.com/v1/albums/3j70PDKieTWQAwas3bPHRZ',
#      'id': '3j70PDKieTWQAwas3bPHRZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273183730e8038fa632b2c227da',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02183730e8038fa632b2c227da',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851183730e8038fa632b2c227da',
#        'width': 64}],
#      'name': 'Eye To The Telescope',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3j70PDKieTWQAwas3bPHRZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zzrJD2jXrE9dZ1AklRFcL'},
#       'href': 'https://api.spotify.com/v1/artists/5zzrJD2jXrE9dZ1AklRFcL',
#       'id': '5zzrJD2jXrE9dZ1AklRFcL',
#       'name': 'KT Tunstall',
#       'type': 'artist',
#       'uri': 'spotify:artist:5zzrJD2jXrE9dZ1AklRFcL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBGLM0400102'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0qAMjeQFyd1qD0LDiV8gWp'},
#     'href': 'https://api.spotify.com/v1/tracks/0qAMjeQFyd1qD0LDiV8gWp',
#     'id': '0qAMjeQFyd1qD0LDiV8gWp',
#     'is_local': False,
#     'name': 'Black Horse And The Cherry Tree',
#     'popularity': 59,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0qAMjeQFyd1qD0LDiV8gWp'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1gIC63gC3B7o7FfpPACZQJ'},
#      'href': 'https://api.spotify.com/v1/albums/1gIC63gC3B7o7FfpPACZQJ',
#      'id': '1gIC63gC3B7o7FfpPACZQJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ff5429125128b43572dbdccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ff5429125128b43572dbdccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ff5429125128b43572dbdccd',
#        'width': 64}],
#      'name': '4',
#      'release_date': '2011-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1gIC63gC3B7o7FfpPACZQJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212146,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11102909'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3axkNosdVQLZiq1HakuGhc'},
#     'href': 'https://api.spotify.com/v1/tracks/3axkNosdVQLZiq1HakuGhc',
#     'id': '3axkNosdVQLZiq1HakuGhc',
#     'is_local': False,
#     'name': 'Countdown',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ad046f8b135785f005bf84b63d657299cd6010ee?cid=f5e91626ae484d8a91d5349fd90cd429',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3axkNosdVQLZiq1HakuGhc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2015-12-22T02:52:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#     'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#     'id': 'thedoctorkto',
#     'type': 'user',
#     'uri': 'spotify:user:thedoctorkto'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#        'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#        'id': '5pKCCKE2ajJHZ9KAiaK11H',
#        'name': 'Rihanna',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1G2ZRwcqN6warfakvcPgEs'},
#      'href': 'https://api.spotify.com/v1/albums/1G2ZRwcqN6warfakvcPgEs',
#      'id': '1G2ZRwcqN6warfakvcPgEs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad4ef80be7f5e15d64ac5c25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad4ef80be7f5e15d64ac5c25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad4ef80be7f5e15d64ac5c25',
#        'width': 64}],
#      'name': 'Good Girl Gone Bad: Reloaded',
#      'release_date': '2008-06-02',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1G2ZRwcqN6warfakvcPgEs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 267080,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70734700'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6tXjP6xgPJ7Xr1igrO6bOE'},
#     'href': 'https://api.spotify.com/v1/tracks/6tXjP6xgPJ7Xr1igrO6bOE',
#     'id': '6tXjP6xgPJ7Xr1igrO6bOE',
#     'is_local': False,
#     'name': "Don't Stop The Music",
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6tXjP6xgPJ7Xr1igrO6bOE'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/54nv8jbrm4JoHEZ49Qvjgl/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 9964}

# %%
p10 = sp.user_playlist_tracks(playlist_id="54nv8jbrm4JoHEZ49Qvjgl", offset=0)

# %%
len(p10["items"])
# Out:
# 100

# %%
offset = 0 
playlist = []
p1 = sp.user_playlist_tracks(playlist_id="54nv8jbrm4JoHEZ49Qvjgl", offset=offset)

while offset<10000:
    for i in p1["items"]:
        playlist.append(i)
    offset+=100
    p1 = sp.user_playlist_tracks(playlist_id="54nv8jbrm4JoHEZ49Qvjgl", offset=offset)

# %%
len(playlist)
# Out:
# 9964

# %%
def df_playlist(playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist","album","track_name", "release_date", "track_id"]
    
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    
    for track in playlist_id:
        # Create empty dict
        playlist_features = {}
        print(track)
        break 
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["release_date"] = track["track"]["album"]["release_date"]
        playlist_features["track_id"] = track["track"]["id"]
        

        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])

    return track_df

# %%
playlist[0]["track"]["album"]["release_date"]
# Out:
# '2012-03-12'
