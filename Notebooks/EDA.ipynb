# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# **Business Problem:**
# As the new data analyst for an up-and-coming music streaming platform, I am responsible for building a recommendation system that can provide recommended songs based on users' existing music preferences. Since the team is building a brand new platform, we may not have sufficient data on user's tastes and how they rate songs that they like to listen to. Therefore, I have been tasked with two components: first, to build a classification system that can address the cold start problem and build predicted ratings for new users, and second, to build a recommendation system that can use these predicted ratings to provide recommended songs for a user to listen to. This will allow the platform to build playlists that are tailored to an individual's tastes and hopefully win new customers with this personalized song-recommendation approach.

# %%
#Import necessary packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Import DataFrames
playlist = pd.read_csv('playlistdf')
playlist.drop(['Unnamed: 0'], axis=1, inplace=True)
audio = pd.read_csv('dfaudio')
audio.drop(['Unnamed: 0'], axis=1, inplace=True)
genres = pd.read_csv('dfgenres')
genres.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Before I proceed with data cleaning, I will investigate the information and the shape of the existing dataframes.

# %%
#Explore first 5 rows of playlist dataset 
playlist.head()
# Out:
#           artist               artist_id  \
# 0     Katy Perry  6jJ0s89eD6GaHleKKya26X
# 1    OneRepublic  5Pwc4xIPtQLFEnJriah9YJ
# 2  Amy Winehouse  6Q192DXotxtaysaqNPy5yR
# 3     The Script  3AQRLZ9PuTAozP28Skbq8V
# 4          Adele  4dpARuHxo51G3z768sgnrY
#
#                                                album  \
# 0  Katy Perry - Teenage Dream: The Complete Confe...
# 1                                  Dreaming Out Loud
# 2                                      Back To Black
# 3                                         The Script
# 4                                                 21
#
#                    track_name release_date  popularity  is_explicit  \
# 0                    Firework   2012-03-12          74        False
# 1                  All We Are   2007-01-01          40        False
# 2               Wake Up Alone   2006-01-01           0        False
# 3  The Man Who Can't Be Moved   2008-09-08          58        False
# 4         Rolling in the Deep   2011-01-19          48        False
#
#                  track_id
# 0  4lCv7b86sLynZbXhfScfm2
# 1  1Jx69b09LKTuBQxkEiFfVX
# 2  4u83mwF5tUuWlXS86UOXdu
# 3  4Musyaro0NM5Awx8b5c627
# 4  1CkvWZme3pRgbzaxZnTl5X

# %%
#Look at shape of DataFrame
playlist.shape
# Out:
# (9963, 8)

# %%
#Explore first 5 rows of genres dataset 
genres.head()
# Out:
#                 artist_id         artist        genres
# 0  6jJ0s89eD6GaHleKKya26X     Katy Perry     dance pop
# 1  5Pwc4xIPtQLFEnJriah9YJ    OneRepublic     dance pop
# 2  6Q192DXotxtaysaqNPy5yR  Amy Winehouse  british soul
# 3  3AQRLZ9PuTAozP28Skbq8V     The Script   celtic rock
# 4  4dpARuHxo51G3z768sgnrY          Adele  british soul

# %%
#Drop any duplicates in the genres dataframe 
genres = genres.drop_duplicates(subset='artist_id')

# %%
#Look at shape of DataFrame
genres.shape
# Out:
# (3128, 3)

# %%
#Explore first 5 rows of audio dataset 
audio.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.638   0.826    8    -4.968     1       0.0479        0.1390
# 1         0.397   0.817    2    -5.495     1       0.0420        0.0966
# 2         0.384   0.527   11    -5.294     0       0.0269        0.5420
# 3         0.609   0.629   10    -5.024     1       0.0264        0.4250
# 4         0.729   0.756    8    -5.119     1       0.0294        0.1310
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.0803    0.649  124.072  audio_features
# 1          0.000008    0.3160    0.416  158.004  audio_features
# 2          0.000000    0.1560    0.222  100.730  audio_features
# 3          0.000000    0.0978    0.325   99.955  audio_features
# 4          0.000000    0.0527    0.522  104.945  audio_features
#
#                        id                                   uri  \
# 0  4lCv7b86sLynZbXhfScfm2  spotify:track:4lCv7b86sLynZbXhfScfm2
# 1  1Jx69b09LKTuBQxkEiFfVX  spotify:track:1Jx69b09LKTuBQxkEiFfVX
# 2  4u83mwF5tUuWlXS86UOXdu  spotify:track:4u83mwF5tUuWlXS86UOXdu
# 3  4Musyaro0NM5Awx8b5c627  spotify:track:4Musyaro0NM5Awx8b5c627
# 4  1CkvWZme3pRgbzaxZnTl5X  spotify:track:1CkvWZme3pRgbzaxZnTl5X
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4lCv7b86sLyn...
# 1  https://api.spotify.com/v1/tracks/1Jx69b09LKTu...
# 2  https://api.spotify.com/v1/tracks/4u83mwF5tUuW...
# 3  https://api.spotify.com/v1/tracks/4Musyaro0NM5...
# 4  https://api.spotify.com/v1/tracks/1CkvWZme3pRg...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4lCv...       227880
# 1  https://api.spotify.com/v1/audio-analysis/1Jx6...       266227
# 2  https://api.spotify.com/v1/audio-analysis/4u83...       221200
# 3  https://api.spotify.com/v1/audio-analysis/4Mus...       241467
# 4  https://api.spotify.com/v1/audio-analysis/1Ckv...       228293
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               4
# 4               4

# %%
#Look at shape of DataFrame
audio.shape
# Out:
# (9963, 18)

# %%
#Rename audio's 'id' column to 'track_id'
audio = audio.rename({'id': 'track_id'}, axis=1)

# %% [markdown]
# #### Merge DataFrames

# %% [markdown]
# I will now merge the dataframes so that I can work with one final dataframe that contains all the relevant information.

# %%
#Merge the playlist and audio dataframes on "track id"
dftemp = pd.merge(playlist, audio, on='track_id', how='inner')

# %%
#Look at shape of merged DataFrame
dftemp.shape
# Out:
# (10003, 25)

# %%
#Merge the resulting dataframe with the genres df on "artist id"
df = pd.merge(dftemp, genres, on='artist_id', how='inner')

# %%
#Look at info of new dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10003 entries, 0 to 10002
# Data columns (total 27 columns):
# artist_x            10003 non-null object
# artist_id           10003 non-null object
# album               10003 non-null object
# track_name          10003 non-null object
# release_date        10003 non-null object
# popularity          10003 non-null int64
# is_explicit         10003 non-null bool
# track_id            10003 non-null object
# danceability        10003 non-null float64
# energy              10003 non-null float64
# key                 10003 non-null int64
# loudness            10003 non-null float64
# mode                10003 non-null int64
# speechiness         10003 non-null float64
# acousticness        10003 non-null float64
# instrumentalness    10003 non-null float64
# liveness            10003 non-null float64
# valence             10003 non-null float64
# tempo               10003 non-null float64
# type                10003 non-null object
# uri                 10003 non-null object
# track_href          10003 non-null object
# analysis_url        10003 non-null object
# duration_ms         10003 non-null int64
# time_signature      10003 non-null int64
# artist_y            10003 non-null object
# genres              10003 non-null object
# dtypes: bool(1), float64(9), int64(5), object(12)
# memory usage: 2.1+ MB

# %%
#Drop duplicated artist column 
df.drop(['artist_y'], axis=1, inplace=True)

# %%
#Rename artist_x column to just be "artist"
df.rename(columns={'artist_x':'artist'}, inplace=True)

# %% [markdown]
# I now have a dataframe that includes all the information from the three original dataframes.

# %%
#Look at final dataframe again 
df.head()
# Out:
#        artist               artist_id  \
# 0  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 1  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 2  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 3  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 4  Katy Perry  6jJ0s89eD6GaHleKKya26X
#
#                                                album  \
# 0  Katy Perry - Teenage Dream: The Complete Confe...
# 1  Katy Perry - Teenage Dream: The Complete Confe...
# 2  Katy Perry - Teenage Dream: The Complete Confe...
# 3                                     PRISM (Deluxe)
# 4                                    One Of The Boys
#
#                      track_name release_date  popularity  is_explicit  \
# 0                      Firework   2012-03-12          74        False
# 1              California Gurls   2012-03-12          73        False
# 2  Last Friday Night (T.G.I.F.)   2012-03-12          74        False
# 3                          Roar   2013-01-01           0        False
# 4               I Kissed A Girl   2008-06-17          73        False
#
#                  track_id  danceability  energy  ...  liveness  valence  \
# 0  4lCv7b86sLynZbXhfScfm2         0.638   0.826  ...    0.0803    0.649
# 1  6tS3XVuOyu10897O3ae7bi         0.791   0.754  ...    0.1630    0.425
# 2  455AfCsOhhLPRc68sE01D8         0.649   0.815  ...    0.6710    0.765
# 3  3bDGwl0X3EjQmIyFD1uif5         0.560   0.756  ...    0.5500    0.404
# 4  14iN3o8ptQ8cFVZTEmyQRV         0.699   0.760  ...    0.1320    0.696
#
#      tempo            type                                   uri  \
# 0  124.072  audio_features  spotify:track:4lCv7b86sLynZbXhfScfm2
# 1  125.014  audio_features  spotify:track:6tS3XVuOyu10897O3ae7bi
# 2  126.030  audio_features  spotify:track:455AfCsOhhLPRc68sE01D8
# 3  179.771  audio_features  spotify:track:3bDGwl0X3EjQmIyFD1uif5
# 4  129.996  audio_features  spotify:track:14iN3o8ptQ8cFVZTEmyQRV
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4lCv7b86sLyn...
# 1  https://api.spotify.com/v1/tracks/6tS3XVuOyu10...
# 2  https://api.spotify.com/v1/tracks/455AfCsOhhLP...
# 3  https://api.spotify.com/v1/tracks/3bDGwl0X3EjQ...
# 4  https://api.spotify.com/v1/tracks/14iN3o8ptQ8c...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4lCv...       227880
# 1  https://api.spotify.com/v1/audio-analysis/6tS3...       234653
# 2  https://api.spotify.com/v1/audio-analysis/455A...       230747
# 3  https://api.spotify.com/v1/audio-analysis/3bDG...       223546
# 4  https://api.spotify.com/v1/audio-analysis/14iN...       179640
#
#    time_signature     genres
# 0               4  dance pop
# 1               4  dance pop
# 2               4  dance pop
# 3               4  dance pop
# 4               4  dance pop
#
# [5 rows x 26 columns]

# %% [markdown]
# The next step will be to actually clean some of the columns in my dataset. Firstly, release_date will need to be transformed to a datetime format, I will turn whether the song is explicit or not into a binary variable, and will drop unnecessary columns for the analysis.

# %%
#Turn release_date into a Datetime object 
df['release_date'] = pd.to_datetime(df['release_date'], format='%Y/%m/%d')

# %%
#Print the value counts of the 'is_explicit' variable 
df['is_explicit'].value_counts()
# Out:
# False    9000
# True     1003
# Name: is_explicit, dtype: int64

# %%
#Convert "is_explicit" to a variable that is equal to 1 if True, 0 if False
df['is_explicit'] = df['is_explicit'].astype(int)

# %%
#Print the value counts to ensure they are the same as before 
df['is_explicit'].value_counts()
# Out:
# 0    9000
# 1    1003
# Name: is_explicit, dtype: int64

# %%
#Drop unncessary columns 
df = df.drop(['type', 'uri', 'analysis_url', 'time_signature', 'track_href'], axis=1)

# %% [markdown]
# Next, as later in the project I will be building a song recommendation system, it is important to see what can be used as a proxy for ratings. In the meantime, there is a column "popularity" which determines how popular a song is, based on how many times it was played. I will investigate, clean and manipulate this variable below.

# %%
#Explore the value counts of popularity 
df['popularity'].value_counts()
# Out:
# 0     2964
# 43     163
# 44     155
# 45     150
# 47     147
#       ...
# 83       9
# 84       6
# 85       5
# 86       2
# 87       1
# Name: popularity, Length: 88, dtype: int64

# %% [markdown]
# We see many songs that have a popularity of 0 which either means a) the popularity is not known or b) the song is quite old (according to the Spotify API documentation, popularity is indicated by play counts, and older songs may be played less). Therefore, these songs could skew our popularity results as they influence the scale of our popularity variable.

# %%
#Remove any popularity values that are equal to 0
df['popularity'] = df['popularity'][df['popularity'] != 0]

# %%
#Check for NA values 
df.isna().sum()
# Out:
# artist                 0
# artist_id              0
# album                  0
# track_name             0
# release_date           0
# popularity          2964
# is_explicit            0
# track_id               0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# duration_ms            0
# genres                 0
# dtype: int64

# %%
#Drop NA values 
df.dropna(inplace=True)

# %%
#Check the value counts again
df['popularity'].value_counts()
# Out:
# 43.0    163
# 44.0    155
# 45.0    150
# 47.0    147
# 41.0    145
#        ...
# 83.0      9
# 84.0      6
# 85.0      5
# 86.0      2
# 87.0      1
# Name: popularity, Length: 87, dtype: int64

# %%
#Look at the describe function to determine the distribution of popularity 
df['popularity'].describe()
# Out:
# count    7039.000000
# mean       43.774968
# std        18.690110
# min         1.000000
# 25%        31.000000
# 50%        44.000000
# 75%        58.000000
# max        87.000000
# Name: popularity, dtype: float64

# %%
#Plot a histogram of the frequency of certain popularity values
plt.hist(df['popularity'],bins='auto')
plt.xlabel('Value of Popularity')
plt.ylabel('Frequency of Popularity')
plt.show()

# %%
#Plot the KDE graph for popularity 
df['popularity'].plot(kind='kde', figsize = (12,6))
plt.show()

# %% [markdown]
# For the classification problem, I will look to see if different song features, particularly audio features, have an impact on the song's popularity. Right now, however, popularity ranges across many values between 0 and 100 and may be difficult to interpret for a classification problem. As a result, I will create a new variable, "ratings", that is on a scale of 1-5, based on the popularity metric. This 1-5 scale will make the target variable easier to interpret when we are performing our classification models.

# %%
#Create a binned variable for popularity as a proxy for our ratings
df['ratings'] = df['popularity'].apply(lambda x: 1 if x <= 20 
                                       else 2 if x>= 21 and x<40 
                                       else 3 if x>=40 and x<60
                                       else 4 if x>=60 and x<75 
                                       else 5)

# %%
#Plot a histogram of the frequency of certain popularity values
plt.hist(df['ratings'],bins='auto')
plt.xlabel('Value of Rating')
plt.ylabel('Frequency of Rating')
plt.show()

# %% [markdown]
# The distribution of the ratings appears similar to the distribution of popularity, so it looks like ratings will be a fair proxy for popularity. We will use the ratings feature in our analysis going forward in order for ease of classification.

# %%
#Drop 'popularity'; will be looking at 'ratings' instead
df = df.drop(['popularity'], axis=1)

# %%
#Plot the top 20 highest rated songs using our new 'ratings' proxy 
plt.figure(figsize=(10,5))
topsongs = df.groupby('track_name').mean()['ratings'].sort_values(ascending=False).head(20)
sns.barplot(topsongs.index, topsongs.values)
plt.title('Top 20 Highest Rated Songs')
plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Plot the top 10 highest rated artists 
plt.figure(figsize=(10,5))
topartists = df.groupby('artist').mean()['ratings'].sort_values(ascending=False).head(10)
sns.barplot(topartists.index, topartists.values)
plt.title('Top 10 Highest Rated Artists')
plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Plot the top 10 highest rated albums
plt.figure(figsize=(10,5))
topalbums = df.groupby('album').mean()['ratings'].sort_values(ascending=False).head(10)
sns.barplot(topalbums.index, topalbums.values)
plt.title('Top 10 Highest Rated Albums')
plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Next we will look at correlation and determine if any explanatory variables are strongly correlated with our target variable, ratings.

# %%
#Look at correlation of entire dataframe
df.corr()
# Out:
#                   is_explicit  danceability    energy       key  loudness  \
# is_explicit          1.000000      0.153351  0.018406  0.027415  0.076546
# danceability         0.153351      1.000000  0.101010  0.015244  0.107487
# energy               0.018406      0.101010  1.000000  0.034786  0.746436
# key                  0.027415      0.015244  0.034786  1.000000  0.022160
# loudness             0.076546      0.107487  0.746436  0.022160  1.000000
# mode                -0.063800     -0.084039 -0.083875 -0.136760 -0.092840
# speechiness          0.282447      0.113334  0.102792  0.045560  0.072843
# acousticness        -0.065111     -0.154216 -0.708906 -0.026942 -0.562088
# instrumentalness    -0.054205     -0.040357 -0.057146 -0.008210 -0.197771
# liveness             0.011126     -0.102767  0.174355 -0.002394  0.102927
# valence             -0.012857      0.433840  0.378728  0.035445  0.196156
# tempo               -0.001205     -0.199575  0.149576  0.007837  0.090763
# duration_ms         -0.011068     -0.117549 -0.026243  0.012772 -0.083645
# ratings              0.022953      0.030226  0.013388  0.007221  0.013949
#
#                       mode  speechiness  acousticness  instrumentalness  \
# is_explicit      -0.063800     0.282447     -0.065111         -0.054205
# danceability     -0.084039     0.113334     -0.154216         -0.040357
# energy           -0.083875     0.102792     -0.708906         -0.057146
# key              -0.136760     0.045560     -0.026942         -0.008210
# loudness         -0.092840     0.072843     -0.562088         -0.197771
# mode              1.000000    -0.088781      0.090695         -0.013871
# speechiness      -0.088781     1.000000     -0.042497         -0.059045
# acousticness      0.090695    -0.042497      1.000000          0.045063
# instrumentalness -0.013871    -0.059045      0.045063          1.000000
# liveness         -0.028910     0.094226     -0.102091         -0.020306
# valence          -0.017626     0.062498     -0.237942         -0.089811
# tempo            -0.001406     0.065314     -0.115362          0.012964
# duration_ms       0.000336    -0.065500     -0.042809          0.099678
# ratings           0.003680    -0.004399     -0.019697         -0.056880
#
#                   liveness   valence     tempo  duration_ms   ratings
# is_explicit       0.011126 -0.012857 -0.001205    -0.011068  0.022953
# danceability     -0.102767  0.433840 -0.199575    -0.117549  0.030226
# energy            0.174355  0.378728  0.149576    -0.026243  0.013388
# key              -0.002394  0.035445  0.007837     0.012772  0.007221
# loudness          0.102927  0.196156  0.090763    -0.083645  0.013949
# mode             -0.028910 -0.017626 -0.001406     0.000336  0.003680
# speechiness       0.094226  0.062498  0.065314    -0.065500 -0.004399
# acousticness     -0.102091 -0.237942 -0.115362    -0.042809 -0.019697
# instrumentalness -0.020306 -0.089811  0.012964     0.099678 -0.056880
# liveness          1.000000  0.042265  0.031792    -0.026420 -0.031056
# valence           0.042265  1.000000  0.033834    -0.181100  0.070866
# tempo             0.031792  0.033834  1.000000    -0.027558 -0.012817
# duration_ms      -0.026420 -0.181100 -0.027558     1.000000  0.082336
# ratings          -0.031056  0.070866 -0.012817     0.082336  1.000000

# %%
#Look only at correlation with our target variable, 'ratings'
df.corr()['ratings']
# Out:
# is_explicit         0.022953
# danceability        0.030226
# energy              0.013388
# key                 0.007221
# loudness            0.013949
# mode                0.003680
# speechiness        -0.004399
# acousticness       -0.019697
# instrumentalness   -0.056880
# liveness           -0.031056
# valence             0.070866
# tempo              -0.012817
# duration_ms         0.082336
# ratings             1.000000
# Name: ratings, dtype: float64

# %% [markdown]
# At a first glance, it looks like most variables have low correlation with the target variable. I'll also look at variables to see if they are correlated with each other, in order to investigate potential multicollinearity.

# %%
#Create new DataFrame which stacks the absolute values of the correlations and sorts them
df2 = df.corr().abs().stack().reset_index().sort_values(0, ascending=False)

#Create a 'pairs' column that groups the two variables whose correlations are being compared
df2['pairs'] = list(zip(df2.level_0, df2.level_1))

#Set this 'pairs' column as the index
df2.set_index(['pairs'], inplace = True)

#Drop the columns level_1 and level_0
df2.drop(columns=['level_1', 'level_0'], inplace = True)

# Create a column 'cc' for correlation coefficient
df2.columns = ['cc']

#Drop dataframe duplicates 
df2.drop_duplicates(inplace=True)

#Display absolute correlations that are greater than 0.70
df2[(df2.cc>.70) & (df2.cc<1)]
# Out:
#                               cc
# pairs
# (loudness, energy)      0.746436
# (acousticness, energy)  0.708906

# %% [markdown]
# The results are not surprising; it makes sense that the energy of a song would be correlated to how loud it is, since energetic songs are fast, loud and noisy. It also makes sense that energy and acousticness are correlated; songs that are acoustic tend to be slower, and lower energy, and therefore it is reasonable to assume that these two features are correlated.

# %% [markdown]
# ### Classification Analysis EDA

# %% [markdown]
# For our classification problem, we will look at how certain audio features can predict a song's rating.

# %%
#First, let's plot a histogram for each column to preview their distributions 
df.hist(figsize=(18,15), bins='auto');

# %% [markdown]
# Several of these variables contain relatively normal distributions (danceability, duration, liveness, loudness, and tempo) while others are clearly binary variables (mode, is_explicit, ratings).

# %% [markdown]
# The next step in EDA will be "Feature Engineering". Since ratings were built from the popularity variable, which calculates a song's popularity based on how many times it was played, one could assume that there is a relationship between the songs' release date and how often it is played; newer songs will likely be played more, older songs less. There are, however, as shown below, many release dates in our dataset (1669 to be exact). Therefore, I will generate a feature that takes note of which decade the song was released in, and then will use this as a way to determine if newer or older songs impact the song's popularity.

# %%
#Look at the number of unique release dates 
df['release_date'].nunique()
# Out:
# 1669

# %%
#Generate a 'year' variable which extracts the year from the release date 
df['year']=pd.to_datetime(df['release_date'], format='%m/%d/%Y').dt.year

# %%
#Plot a histogram of the years to see which ones show up more frequently in our dataset 
df['year'].hist()

# %%
#Print the number of unique years 
df['year'].nunique()
# Out:
# 64

# %%
#Top 5 Years with the most tracks 
plt.figure(figsize=(12,7))
topyear = df.groupby('year').size().sort_values(ascending=False).head(5)
sns.barplot(topyear.index, topyear.values)
plt.title('Top 5 most popular years')
plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Since the goal is to determine if the year that the song is from impacts the song rating, with 64 years, it may be difficult to see if one specific year has an impact vs. another, since there are 64 unique years in our dataset. As a result, we will first transform the 'year' feature into a 'decade' feature, and then will turn this decade feature into a categorical variable to determine its impact on song ratings.

# %%
#adding a new feature "decade" that breaks down songs that are from the 2010s, 2000s, etc.
#if the song is from a decade it will be assigned the first year of that decade
#i.e. if a song is from 1975, the decade variable will have the variable as "1970", as in from the 1970s
df['decade'] = df['year'].apply(lambda x: 1950 if x<1960 
                                        else 1960 if x>=1960 and x<1970 
                                        else 1970 if x>=1970 and x<1980
                                        else 1980 if x>=1980 and x<1990
                                        else 1990 if x>=1990 and x<2000
                                        else 2000 if x>=2000 and x<2010
                                        else 2010)

# %%
#Drop year and release date as they are no longer needed since there is the decade variable
audio = df.drop(['release_date'], axis=1)

# %%
#Display 5 rows of audio again
audio.head()
# Out:
#        artist               artist_id  \
# 0  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 1  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 2  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 4  Katy Perry  6jJ0s89eD6GaHleKKya26X
# 6  Katy Perry  6jJ0s89eD6GaHleKKya26X
#
#                                                album  \
# 0  Katy Perry - Teenage Dream: The Complete Confe...
# 1  Katy Perry - Teenage Dream: The Complete Confe...
# 2  Katy Perry - Teenage Dream: The Complete Confe...
# 4                                    One Of The Boys
# 6  Katy Perry - Teenage Dream: The Complete Confe...
#
#                      track_name  is_explicit                track_id  \
# 0                      Firework            0  4lCv7b86sLynZbXhfScfm2
# 1              California Gurls            0  6tS3XVuOyu10897O3ae7bi
# 2  Last Friday Night (T.G.I.F.)            0  455AfCsOhhLPRc68sE01D8
# 4               I Kissed A Girl            0  14iN3o8ptQ8cFVZTEmyQRV
# 6                    Part Of Me            0  1nZzRJbFvCEct3uzu04ZoL
#
#    danceability  energy  key  loudness  ...  acousticness  instrumentalness  \
# 0         0.638   0.826    8    -4.968  ...      0.139000          0.000000
# 1         0.791   0.754    0    -3.729  ...      0.004460          0.000000
# 2         0.649   0.815    3    -3.796  ...      0.001250          0.000043
# 4         0.699   0.760    5    -3.173  ...      0.002230          0.000000
# 6         0.678   0.918    5    -4.630  ...      0.000417          0.000000
#
#    liveness  valence    tempo  duration_ms     genres  ratings  year  decade
# 0    0.0803    0.649  124.072       227880  dance pop        4  2012    2010
# 1    0.1630    0.425  125.014       234653  dance pop        4  2012    2010
# 2    0.6710    0.765  126.030       230747  dance pop        4  2012    2010
# 4    0.1320    0.696  129.996       179640  dance pop        4  2008    2000
# 6    0.0744    0.769  130.028       216160  dance pop        4  2012    2010
#
# [5 rows x 22 columns]

# %%
#Turn the decade variable into a dummy variable
df_new = audio['decade']
df_new = pd.get_dummies(df_new, drop_first=True, prefix='decade')

# %%
#Confirm that the df_new dataframe contains our dummy variables 
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7039 entries, 0 to 10002
# Data columns (total 6 columns):
# decade_1960    7039 non-null uint8
# decade_1970    7039 non-null uint8
# decade_1980    7039 non-null uint8
# decade_1990    7039 non-null uint8
# decade_2000    7039 non-null uint8
# decade_2010    7039 non-null uint8
# dtypes: uint8(6)
# memory usage: 96.2 KB

# %%
#Join the new dataframe of our dummies with our original dataset 
df = pd.concat([audio, df_new], axis=1, join='inner')

# %%
#Confirm all the new columns are in our new dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7039 entries, 0 to 10002
# Data columns (total 28 columns):
# artist              7039 non-null object
# artist_id           7039 non-null object
# album               7039 non-null object
# track_name          7039 non-null object
# is_explicit         7039 non-null int64
# track_id            7039 non-null object
# danceability        7039 non-null float64
# energy              7039 non-null float64
# key                 7039 non-null int64
# loudness            7039 non-null float64
# mode                7039 non-null int64
# speechiness         7039 non-null float64
# acousticness        7039 non-null float64
# instrumentalness    7039 non-null float64
# liveness            7039 non-null float64
# valence             7039 non-null float64
# tempo               7039 non-null float64
# duration_ms         7039 non-null int64
# genres              7039 non-null object
# ratings             7039 non-null int64
# year                7039 non-null int64
# decade              7039 non-null int64
# decade_1960         7039 non-null uint8
# decade_1970         7039 non-null uint8
# decade_1980         7039 non-null uint8
# decade_1990         7039 non-null uint8
# decade_2000         7039 non-null uint8
# decade_2010         7039 non-null uint8
# dtypes: float64(9), int64(7), object(6), uint8(6)
# memory usage: 1.3+ MB

# %%
#Drop the decade variable 
df = df.drop(['decade'], axis=1)

# %% [markdown]
# Several variables are not on a 0-1 scale; such as loudness, tempo, duration, mode and key. I will look to see if these variables have any outliers and if so, if they should be removed.

# %%
#Create boxplots to identify outliers for loudness, tempo, duration and mode
plt.figure(figsize=(16,8))
plt.subplot(221)
sns.boxplot(x=df['loudness'])
plt.subplot(222)
sns.boxplot(x=df['tempo'])
plt.subplot(223)
sns.boxplot(x=df['duration_ms'])
plt.subplot(224)
sns.boxplot(x=df['mode'])

# %% [markdown]
# There are several outliers in loudness, tempo and duration that could influence our results. For now, I will only drop very *extreme* outliers, but will consider dropping others later on, depending on the models' results.

# %%
#Remove extreme outliers for loudness
df = df[df['loudness']>-25]

# %%
#Remove extreme outliers for duration
df = df[(df['duration_ms']>50000) & (df['duration_ms']<550000)]

# %%
#Remove extreme outliers for tempo
df = df[df['tempo']>0]

# %%
#Let's relook at these variables' box plots again 
plt.figure(figsize=(16,8))
plt.subplot(221)
sns.boxplot(x=df['loudness'])
plt.subplot(222)
sns.boxplot(x=df['tempo'])
plt.subplot(223)
sns.boxplot(x=df['duration_ms'])

# %% [markdown]
# These graphs look a bit better. There are, however, still several outliers in these variables, as we only removed extreme outliers from our dataset. I will first see how the models perform, and depending on the results, will look into adjusting the outliers further, if need be.

# %% [markdown]
# Additionally, several of the audio features are calculated on the same scale. Acousticness, energy, danceability, instrumentalness, liveness, speechiness, and valence all are measured on a 0-1 scale; the closer to 1, the higher the amount of that feature. Let's quickly confirm this with the df.describe method:

# %%
#Print df summary statistics
df.describe()
# Out:
#        is_explicit  danceability       energy          key     loudness  \
# count  7031.000000   7031.000000  7031.000000  7031.000000  7031.000000
# mean      0.103257      0.586386     0.665741     5.141232    -6.877535
# std       0.304316      0.143441     0.205349     3.577207     3.092478
# min       0.000000      0.069200     0.023100     0.000000   -24.446000
# 25%       0.000000      0.495000     0.536000     2.000000    -8.223500
# 50%       0.000000      0.594000     0.705000     5.000000    -6.166000
# 75%       0.000000      0.688000     0.828000     8.000000    -4.748000
# max       1.000000      0.979000     0.993000    11.000000    -0.276000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  7031.000000  7031.000000   7031.000000       7031.000000  7031.000000
# mean      0.664344     0.069115      0.227444          0.034413     0.183384
# std       0.472253     0.066492      0.276292          0.132372     0.146511
# min       0.000000     0.022400      0.000005          0.000000     0.015300
# 25%       0.000000     0.034400      0.015850          0.000000     0.094100
# 50%       1.000000     0.045200      0.095400          0.000009     0.123000
# 75%       1.000000     0.071200      0.362000          0.000913     0.231000
# max       1.000000     0.907000      0.995000          0.983000     0.990000
#
#        ...        tempo    duration_ms      ratings         year  decade_1960  \
# count  ...  7031.000000    7031.000000  7031.000000  7031.000000  7031.000000
# mean   ...   121.025446  224853.622813     2.738444  2010.368511     0.009671
# std    ...    28.311506   46407.265874     1.021671    10.183733     0.097874
# min    ...    34.082000  105147.000000     1.000000  1948.000000     0.000000
# 25%    ...    99.916500  196233.500000     2.000000  2009.000000     0.000000
# 50%    ...   119.966000  218960.000000     3.000000  2015.000000     0.000000
# 75%    ...   138.123500  246605.000000     3.000000  2016.000000     0.000000
# max    ...   218.356000  549080.000000     5.000000  2018.000000     1.000000
#
#        decade_1970  decade_1980  decade_1990  decade_2000  decade_2010
# count  7031.000000  7031.000000  7031.000000  7031.000000  7031.000000
# mean      0.018632     0.031290     0.049211     0.142796     0.746693
# std       0.135230     0.174113     0.216323     0.349890     0.434936
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     1.000000
# 75%       0.000000     0.000000     0.000000     0.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# Now, I would like to take a look at the means of these features across the entire playlist and see how they compare to one another.

# %%
#Plot the means of the features that are on a 0-1 scale 
scale = ['danceability', 'energy', 'speechiness', 'acousticness','instrumentalness', 'liveness', 'valence']
df[scale].mean().plot(kind='bar')

# %% [markdown]
# We see here that our playlists' attributes are overall songs with high danceability (songs suitable for dancing), high energy (high intensity and noise) and high valence (happy and cheery). It appears that we have a playlist full of fun, happy, dance songs!

# %%
#Look at the value counts of our ratings 
df['ratings'].value_counts()
# Out:
# 3    2659
# 2    1898
# 4    1325
# 1     891
# 5     258
# Name: ratings, dtype: int64

# %% [markdown]
# ### Comparative Graphs

# %% [markdown]
# Further, I would like to determine if the distribution of features differs across different ratings. If we do see major differences in the distributions of features for a rating of 1 vs. a rating of 5, then this is a good indication that certain increases/decreases in certain features will impact our ability to predict the rating of a song. Before I conduct any modeling, I will look at the distrubtion of several of our continuous features.

# %% [markdown]
# #### a. Danceability

# %%
#Plot KDE graph for danceability across all ratings 
df.groupby("ratings").danceability.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: danceability, dtype: object

# %%
#Create a variable that lists ratings in order 
numberslist = [1,2,3,4,5]

# %%
# Plot histograms for danceability across 5 ratings 
fig, axes = plt.subplots(1, 5, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive']

for i, (ax, rating) in enumerate(zip(axes.flatten(), numberslist)):
    x = df.loc[df.ratings==rating, 'danceability']
    ax.hist(x, alpha=0.5, bins=100, density=True, stacked=True, label=str(rating), color=colors[i])
    ax.set_title(rating)

plt.suptitle('Probability Histogram of Danceability across 5 Ratings', y=1.05, size=10)
ax.set_xlim(0, 1); ax.set_ylim(0, 6);
plt.tight_layout();

# %% [markdown]
# Danceability has a similar probability distribution across ratings 1-4; the only notable difference is the songs that have 5 ratings that higher probability of high danceability scores. This is also proven from the KDE plot above, where ratings 1-4 follow a similar pattern, but the KDE for a rating of 5 is shifted slightly to the right.

# %% [markdown]
# #### b. Energy

# %%
#Plot KDE graph for energy across all ratings 
df.groupby("ratings").energy.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: energy, dtype: object

# %% [markdown]
# For energy, all the ratings follow a similar pattern. Ratings 3 and 4 have the highest peaks, however the peak for rating 5 is a slightly higher energy value than these other high-rated songs.

# %% [markdown]
# #### c. Speechiness

# %%
#Plot KDE graph for speechiness across all ratings 
df.groupby("ratings").speechiness.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: speechiness, dtype: object

# %%
# Plot histograms for speechiness across 5 ratings 
fig, axes = plt.subplots(1, 5, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive']

for i, (ax, rating) in enumerate(zip(axes.flatten(), numberslist)):
    x = df.loc[df.ratings==rating, 'speechiness']
    ax.hist(x, alpha=0.5, bins=100, density=True, stacked=True, label=str(rating), color=colors[i])
    ax.set_title(rating)

plt.suptitle('Probability Histogram of Speechiness across 5 Ratings', y=1.05, size=10)
ax.set_xlim(0, 1); ax.set_ylim(0, 30);
plt.tight_layout();

# %% [markdown]
# 'Speechiness', according to the API, is defined as the presence of spoken-like words in a song. The more speechiness a song has, the more it resembles a podcast, or an audiobook. When looking at the KDE graphs, higher rated songs with ratings of 3 and 4 have the highest density of speechiness, while songs with a rating of 5 peak at a significantly lower density than other songs. When looking at the histograms, however, it appears that all ratings follow a similar distribution pattern, so the differences in the distribution of speechiness across ratings are relatively insignificant.

# %% [markdown]
# #### d. Acousticness

# %%
#Plot KDE graph for acousticness across all ratings 
df.groupby("ratings").acousticness.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: acousticness, dtype: object

# %%
# Plot histograms for acousticness across 5 ratings 
fig, axes = plt.subplots(1, 5, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive']

for i, (ax, rating) in enumerate(zip(axes.flatten(), numberslist)):
    x = df.loc[df.ratings==rating, 'acousticness']
    ax.hist(x, alpha=0.5, bins=100, density=True, stacked=True, label=str(rating), color=colors[i])
    ax.set_title(rating)

plt.suptitle('Probability Histogram of Acousticness across 5 Ratings', y=1.05, size=10)
ax.set_xlim(0, 1); ax.set_ylim(0, 10);
plt.tight_layout();

# %% [markdown]
# Songs across all ratings show very simliar distributions of Acousticness, with no major differences across the ratings scale.

# %% [markdown]
# #### e. Instrumentalness

# %%
#Plot KDE graph for instrumentalness across all ratings 
df.groupby("ratings").instrumentalness.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: instrumentalness, dtype: object

# %% [markdown]
# For instrumentalness, songs with a rating of 5 have more songs that are valued at 0, however all of the ratings here follow a similar distribution, and there are no major differences across the ratings.

# %% [markdown]
# #### f. Liveness

# %%
#Plot KDE graph for liveness across all ratings 
df.groupby("ratings").liveness.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: liveness, dtype: object

# %%
# Plot histograms for liveness across 5 ratings 
fig, axes = plt.subplots(1, 5, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive']

for i, (ax, rating) in enumerate(zip(axes.flatten(), numberslist)):
    x = df.loc[df.ratings==rating, 'liveness']
    ax.hist(x, alpha=0.5, bins=100, density=True, stacked=True, label=str(rating), color=colors[i])
    ax.set_title(rating)

plt.suptitle('Probability Histogram of Liveness across 5 Ratings', y=1.05, size=10)
ax.set_xlim(0, 1); ax.set_ylim(0, 15);
plt.tight_layout();

# %% [markdown]
# Ratings 1 through 5 have similar distributions, all with a peak inbetween 0 and 0.25. Overall, the liveness of the songs in this playlist skew towards the left, but there are no notable differences between songs that have low or high ratings.

# %% [markdown]
# #### g. Valence

# %%
#Plot KDE graph for valence across all ratings 
df.groupby("ratings").valence.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: valence, dtype: object

# %%
# Plot histograms for valence across 5 ratings 
fig, axes = plt.subplots(1, 5, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive']

for i, (ax, rating) in enumerate(zip(axes.flatten(), numberslist)):
    x = df.loc[df.ratings==rating, 'valence']
    ax.hist(x, alpha=0.5, bins=100, density=True, stacked=True, label=str(rating), color=colors[i])
    ax.set_title(rating)

plt.suptitle('Probability Histogram of Valence across 5 Ratings', y=1.05, size=10)
ax.set_xlim(0, 1); ax.set_ylim(0, 5);
plt.tight_layout();

# %% [markdown]
# When looking at the histograms, it appears that all ratings have similar distributions for valence. On the KDE graph, interestingly, the rating of 5, unlike the other ratings, appears to have two modes; around 0.5 and again around 0.80. Overall, more songs that have a 5 rating have higher valence values.

# %% [markdown]
# #### h. Loudness

# %%
#Plot KDE graph for loudness across all ratings 
df.groupby("ratings").loudness.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: loudness, dtype: object

# %% [markdown]
# Loudness shows similar distributions across ratings. The distribution for 4 and 5 have slightly higher levels of loudness than lower ratings, but this difference is negligible.

# %% [markdown]
# ### i. Duration

# %%
#Plot KDE graph for duration across all ratings 
df.groupby("ratings").duration_ms.plot(kind='kde', legend=True, figsize=(12,6))
# Out:
# ratings
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: duration_ms, dtype: object

# %% [markdown]
# The distribution for duration is similar across ratings, however songs with ratings of 5 have slightly highly levels of duration than other rated songs.

# %% [markdown]
# ### Years EDA

# %%
#Top 10 Years with the highest rated songs 
plt.figure(figsize=(12,7))
topyear = df.groupby('year').mean()['ratings'].sort_values(ascending=False).head(10)
sns.barplot(topyear.index, topyear.values)
plt.title('Top 10 years with highest rated songs')
plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Top 10 Years with the most songs in the playlist
plt.figure(figsize=(12,7))
topyear = df.groupby('year').size().sort_values(ascending=False).head(10)
sns.barplot(topyear.index, topyear.values)
plt.title('Top 10 most popular years')
plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Interestingly, while the playlist mostly contains songs from newer years (particlarly 2015-2017), these are not the years that have the highest rated songs - from the graph above, the years that have the highest overall ratings of songs are songs from the 1950s, 60s and 70s.

# %%
#Drop the 'year' column, as I will use 'decades' variables instead going forward 
df = df.drop(['year'], axis=1)

# %% [markdown]
# ### Genres EDA

# %%
#Print the unique number of genres 
df['genres'].nunique()
# Out:
# 478

# %%
#Convert genres to a string 
df['genres'] = df['genres'].astype('str')

# %%
#Look at the value counts of the genres 
df['genres'].value_counts()
# Out:
# dance pop                     1013
# unknown                        263
# alternative dance              258
# electropop                     226
# album rock                     205
#                               ...
# latin arena pop                  1
# dansktop                         1
# progressive house                1
# nouvelle chanson francaise       1
# boston hip hop                   1
# Name: genres, Length: 478, dtype: int64

# %%
#Check for NA values
df['genres'].isna().sum()
# Out:
# 0

# %% [markdown]
# Since there are so many unique genre types in our dataset, it would be useful to transform these genres into more general categories (i.e. pop dance and british dance both in the category 'dance'). This will be more useful later on when we are running machine learning models, and can look into transforming these genres into dummy variables.

# %%
#Define a function that assigns genres to genre categories 
def genrecategory(value):
    if 'country' in value:
        return 'country'
    elif 'dance' in value:
        return 'dance'
    elif 'rock' in value:
        return 'rock'
    elif 'indie' in value:
        return 'indie'
    elif 'rap' in value:
        return 'rap'
    elif 'elect' in value:
        return 'electronic'
    elif 'hip hop' in value:
        return 'hip hop'
    elif 'house' in value:
        return 'house'
    elif 'soul' in value:
        return 'soul'
    elif 'acoustic' in value:
        return 'acoustic'
    elif 'emo' in value:
        return 'punk'
    elif 'pop' in value:
        return 'pop'
    elif 'r&b' in value:
        return 'r&b'
    elif 'metal' in value:
        return 'punk'
    elif 'unknown' in value:
        return 'Other'
    elif 'boy band' in value:
        return 'pop'
    elif 'punk' in value:
        return 'punk'
    elif 'permanent wave' in value:
        return 'punk'
    elif 'edm' in value:
        return 'dance'
    elif 'neo mellow' in value:
        return 'pop'
    elif 'hopebeat' in value:
        return 'indie'
    elif 'funk' in value:
        return 'indie'
    elif 'adult standards' in value:
        return 'pop'
    elif 'disney' in value:
        return 'pop'
    elif 'beatlesque' in value:
        return 'rock'
    elif 'reggae fusion' in value:
        return 'indie'
    elif 'hollywood' in value:
        return 'pop'
    else:
        return 'Other'

# %%
#Apply the genre category function to the genres column and add it to our dataframe 
df['genrecategory'] = df['genres'].map(lambda n: genrecategory(n))

# %%
#Turn the decade variable into a dummy variable
df_temp = df['genrecategory']
df_temp = pd.get_dummies(df_temp, drop_first=True, prefix='genre')

# %%
#Join the new dataframe of our dummies with our original dataset 
df = pd.concat([df, df_temp], axis=1, join='inner')

# %%
#Drop unnecessary columns
df = df.drop(['genres'], axis=1)

# %%
#Confirm the new columns have been added to the DataFrame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7031 entries, 0 to 10002
# Data columns (total 39 columns):
# artist              7031 non-null object
# artist_id           7031 non-null object
# album               7031 non-null object
# track_name          7031 non-null object
# is_explicit         7031 non-null int64
# track_id            7031 non-null object
# danceability        7031 non-null float64
# energy              7031 non-null float64
# key                 7031 non-null int64
# loudness            7031 non-null float64
# mode                7031 non-null int64
# speechiness         7031 non-null float64
# acousticness        7031 non-null float64
# instrumentalness    7031 non-null float64
# liveness            7031 non-null float64
# valence             7031 non-null float64
# tempo               7031 non-null float64
# duration_ms         7031 non-null int64
# ratings             7031 non-null int64
# decade_1960         7031 non-null uint8
# decade_1970         7031 non-null uint8
# decade_1980         7031 non-null uint8
# decade_1990         7031 non-null uint8
# decade_2000         7031 non-null uint8
# decade_2010         7031 non-null uint8
# genrecategory       7031 non-null object
# genre_acoustic      7031 non-null uint8
# genre_country       7031 non-null uint8
# genre_dance         7031 non-null uint8
# genre_electronic    7031 non-null uint8
# genre_hip hop       7031 non-null uint8
# genre_house         7031 non-null uint8
# genre_indie         7031 non-null uint8
# genre_pop           7031 non-null uint8
# genre_punk          7031 non-null uint8
# genre_r&b           7031 non-null uint8
# genre_rap           7031 non-null uint8
# genre_rock          7031 non-null uint8
# genre_soul          7031 non-null uint8
# dtypes: float64(9), int64(5), object(6), uint8(19)
# memory usage: 1.3+ MB

# %%
#Create function that counts how many songs there are of each genre 
def genrecounts(df, col, labels):
    count = dict()
    for i in labels: count[i] = 0
    for value in df[col].str.split('|'):
        if type(value) == float and pd.isnull(value): continue
        for i in value: 
            if pd.notnull(i): count[i] += 1
    return count

# %%
#Check the value counts of the genres
df['genrecategory'].value_counts()
# Out:
# dance         1518
# pop           1378
# rock           963
# Other          896
# indie          723
# punk           326
# electronic     282
# hip hop        257
# soul           159
# country        156
# acoustic       118
# r&b            109
# rap            102
# house           44
# Name: genrecategory, dtype: int64

# %%
#Create a new dataframe that contains the genre names and their frequencies 
dataframe = df['genrecategory'].value_counts().rename_axis('genre').reset_index(name='Frequency')

# %%
#Investigate this new dataframe 
print(dataframe)
# Out:
#          genre  Frequency
# 0        dance       1518
# 1          pop       1378
# 2         rock        963
# 3        Other        896
# 4        indie        723
# 5         punk        326
# 6   electronic        282
# 7      hip hop        257
# 8         soul        159
# 9      country        156
# 10    acoustic        118
# 11         r&b        109
# 12         rap        102
# 13       house         44

# %%
#Plot the top music genres using our new dataframe 
plt.figure(figsize=(12,7))
sns.barplot(dataframe['genre'], dataframe['Frequency'])
plt.title('Most Popular Genres')
plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Create a dataframe 'matrix' that only contains the track name and the genre dummies 
matrix = df.drop(['genrecategory', 'is_explicit', 'track_id', 'danceability', 
                  'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 
                  'instrumentalness', 'liveness', 'valence', 'tempo', 
                  'duration_ms', 'ratings', 'decade_1960', 'decade_1970', 
                  'decade_1980', 'decade_1990', 'decade_2000', 'decade_2010', 
                  'artist_id', 'artist', 'album'], axis=1)

# %%
#Create a loop that will plot the top 10 most listened tracks per genre 
for gen in matrix.columns[1:]:
    x = matrix[(matrix[gen]==True)]
    plt.figure(figsize=(8,8))
    topsongs = x.groupby('track_name').size().sort_values(ascending=False).head(10)
    sns.barplot(topsongs.index, topsongs.values)
    plt.title('Top 10 most-listened '+gen[6:]+' tracks')
    plt.xticks(rotation=80);
# Out:
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/adinasteinman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Takeaways

# %% [markdown]
# For audio features, the results show that songs with higher ratings have stronger danceability, energy, valence and durations. Then, interestingly, songs that are from more recent years show up more frequently in the playlist, yet older songs appeared to have higher average ratings overall. The most popular genres in our dataset are dance, pop and rock. Lastly, there are certain songs within each genre that are rated higher, and it will be important to see how our estimated ratings results compare.

# %%
#Save data to a csv file 
df.to_csv('modelingdata')
